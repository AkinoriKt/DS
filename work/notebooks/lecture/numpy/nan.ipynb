# %% [markdown]
# ## NaN

# %%
import numpy as np

# %%
np.log(-100)
# Out:
# /tmp/ipykernel_44336/60392587.py:1: RuntimeWarning: invalid value encountered in log
#   np.log(-100)
# np.float64(nan)

# %%
np.nan
# Out:
# nan

# %%
type(np.nan)
# Out:
# float

# %%
np.isnan(np.log(-100))
# Out:
# /tmp/ipykernel_44336/473003783.py:1: RuntimeWarning: invalid value encountered in log
#   np.isnan(np.log(-100))
# np.True_

# %%
np.log(-100) is np.nan
# Out:
# /tmp/ipykernel_44336/1496133199.py:1: RuntimeWarning: invalid value encountered in log
#   np.log(-100) is np.nan
# False

# %%
np.log(-100) == np.nan
# Out:
# /tmp/ipykernel_44336/1813460688.py:1: RuntimeWarning: invalid value encountered in log
#   np.log(-100) == np.nan
# np.False_
