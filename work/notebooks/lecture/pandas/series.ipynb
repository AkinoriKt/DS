# %%
import pandas as pd

# %%
data = {
    'Name': 'aki',
    'Age': 35,
}

# %%
pd.Series(data)
# Out:
# Name    aki
# Age      35
# dtype: object

# %%
import numpy as  np

# %%
array = np.array([22, 32, 42])
age_series = pd.Series(array)
age_series
# Out:
# 0    22
# 1    32
# 2    42
# dtype: int64

# %%
array = np.array(['John', 'male', 32])
john_series = pd.Series(array, index=['Name', 'Sex', 'Age'])
john_series
# Out:
# Name    John
# Sex     male
# Age       32
# dtype: str

# %%
john_series['Name']
# Out:
# 'John'

# %%
age_series.values
# Out:
# array([22, 32, 42])

# %%
age_series.mean()
# Out:
# np.float64(32.0)
