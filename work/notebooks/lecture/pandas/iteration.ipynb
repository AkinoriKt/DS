# %%
import pandas as pd

df = pd.read_csv('../../../data/raw/lecture/tmdb_5000_movies.csv')

# %%
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
import numpy as np

# %%
np.nan
# Out:
# nan

# %%
def return_nan_if_zero(data):
    if data == 0:
        return np.nan
    return data

# %%
df['budget'].iloc[0]
# Out:
# np.int64(237000000)

# %%
return_nan_if_zero(df['revenue'].iloc[83])
# Out:
# nan

# %%
df[df['revenue'] == 0]
# Out:
#          budget                                             genres  \
# 83     27000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 135   150000000  [{"id": 18, "name": "Drama"}, {"id": 27, "name...
# 265           0  [{"id": 35, "name": "Comedy"}, {"id": 14, "nam...
# 309    84000000  [{"id": 14, "name": "Fantasy"}, {"id": 35, "na...
# 376    90000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# ...         ...                                                ...
# 4797          0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 83                                                  NaN   79698
# ...

# %%
df['budget']
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4798       220000
# 4799         9000
# 4800            0
# 4801            0
# 4802            0
# Name: budget, Length: 4803, dtype: int64

# %%
df['budget'] = df['budget'].apply(return_nan_if_zero)
df['budget']
# Out:
# 0       237000000.0
# 1       300000000.0
# 2       245000000.0
# 3       250000000.0
# 4       260000000.0
#            ...
# 4798       220000.0
# 4799         9000.0
# 4800            NaN
# 4801            NaN
# 4802            NaN
# Name: budget, Length: 4803, dtype: float64

# %%
df.sort_values('budget', ascending=False)
# Out:
#            budget                                             genres  \
# 17    380000000.0  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 1     300000000.0  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 7     280000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000.0  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 4     260000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...           ...                                                ...
# 4795          NaN                      [{"id": 18, "name": "Drama"}]
# 4797          NaN  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4800          NaN  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          NaN                                                 []
# 4802          NaN                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 17    http://disney.go.com/pirates/index-on-stranger...    1865
# ...

# %%
x = lambda x: x+2
x(2)
# Out:
# 4

# %%
x = lambda budget: np.nan if budget == 0 else budget
x(0)
# Out:
# nan

# %%
df = pd.read_csv('../../../data/raw/lecture/tmdb_5000_movies.csv')

# %%
df['budget'] = df['budget'].apply(lambda budget: np.nan if budget == 0 else budget)
df['budget']
# Out:
# 0       237000000.0
# 1       300000000.0
# 2       245000000.0
# 3       250000000.0
# 4       260000000.0
#            ...
# 4798       220000.0
# 4799         9000.0
# 4800            NaN
# 4801            NaN
# 4802            NaN
# Name: budget, Length: 4803, dtype: float64

# %%
df['revenue']
# Out:
# 0       2787965087
# 1        961000000
# 2        880674609
# 3       1084939099
# 4        284139100
#            ...
# 4798       2040920
# 4799             0
# 4800             0
# 4801             0
# 4802             0
# Name: revenue, Length: 4803, dtype: int64

# %%
df['revenue'] = df['revenue'].apply(lambda revenue: np.nan if revenue == 0 else revenue)
df['revenue']
# Out:
# 0       2.787965e+09
# 1       9.610000e+08
# 2       8.806746e+08
# 3       1.084939e+09
# 4       2.841391e+08
#             ...
# 4798    2.040920e+06
# 4799             NaN
# 4800             NaN
# 4801             NaN
# 4802             NaN
# Name: revenue, Length: 4803, dtype: float64

# %%
df = df.dropna(subset=['budget', 'revenue'])
len(df)
# Out:
# 3229

# %%
df['revenue']
# Out:
# 0       2.787965e+09
# 1       9.610000e+08
# 2       8.806746e+08
# 3       1.084939e+09
# 4       2.841391e+08
#             ...
# 4773    3.151130e+06
# 4788    6.000000e+06
# 4792    9.900000e+04
# 4796    4.247600e+05
# 4798    2.040920e+06
# Name: revenue, Length: 3229, dtype: float64

# %%
df['budget']
# Out:
# 0       237000000.0
# 1       300000000.0
# 2       245000000.0
# 3       250000000.0
# 4       260000000.0
#            ...
# 4773        27000.0
# 4788        12000.0
# 4792        20000.0
# 4796         7000.0
# 4798       220000.0
# Name: budget, Length: 3229, dtype: float64

# %%
df['revenue'] - df['budget']
# Out:
# 0       2.550965e+09
# 1       6.610000e+08
# 2       6.356746e+08
# 3       8.349391e+08
# 4       2.413910e+07
#             ...
# 4773    3.124130e+06
# 4788    5.988000e+06
# 4792    7.900000e+04
# 4796    4.177600e+05
# 4798    1.820920e+06
# Length: 3229, dtype: float64

# %%
2.787965e+09 - 237000000.0
# Out:
# 2550965000.0

# %%
df.apply(lambda row: row['revenue'] - row['budget'], axis=1)
# Out:
# 0       2.550965e+09
# 1       6.610000e+08
# 2       6.356746e+08
# 3       8.349391e+08
# 4       2.413910e+07
#             ...
# 4773    3.124130e+06
# 4788    5.988000e+06
# 4792    7.900000e+04
# 4796    4.177600e+05
# 4798    1.820920e+06
# Length: 3229, dtype: float64

# %%
df['profit'] = df.apply(lambda row: row['revenue'] - row['budget'], axis=1)
df.head()
# Out:
#         budget                                             genres  \
# 0  237000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000.0  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000.0  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df.sort_values('profit', ascending=False).head(3)
# Out:
#          budget                                             genres  \
# 0   237000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25  200000000.0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 28  150000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                          homepage      id  \
# 0     http://www.avatarmovie.com/   19995
# 25    http://www.titanicmovie.com     597
# 28  http://www.jurassicworld.com/  135397
#
#                                              keywords original_language  \
# 0   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 25  [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
# 28  [{"id": 1299, "name": "monster"}, {"id": 1718,...                en
#
#     original_title                                           overview  \
# 0           Avatar  In the 22nd century, a paraplegic Marine is di...
# 25         Titanic  84 years later, a 101-year-old woman named Ros...
# ...

# %%
df['profit'].max()
# Out:
# np.float64(2550965087.0)

# %%
df.iloc[df['profit'].idxmax()]
# Out:
# budget                                                        237000000.0
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                     150.437577
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                      2787965087.0
# ...

# %%
df[df['profit'] == df['profit'].max()]
# Out:
#         budget                                             genres  \
# 0  237000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ...  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
#
#   release_date       revenue  runtime  \
# 0   2009-12-10  2.787965e+09    162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average  vote_count        profit
# ...

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0xffff460f6bd0>

# %%
next(df.iterrows())
# Out:
# (0,
#  budget                                                        237000000.0
#  genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#  homepage                                      http://www.avatarmovie.com/
#  id                                                                  19995
#  keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
#  original_language                                                      en
#  original_title                                                     Avatar
#  overview                In the 22nd century, a paraplegic Marine is di...
#  popularity                                                     150.437577
#  production_companies    [{"name": "Ingenious Film Partners", "id": 289...
#  production_countries    [{"iso_3166_1": "US", "name": "United States o...
#  release_date                                                   2009-12-10
# ...

# %%
type(next(df.iterrows()))
# Out:
# tuple

# %%
a, b = next(df.iterrows())
print(a)
print(type(a))
print(b)
print(type(b))
# Out:
# 0
# <class 'int'>
# budget                                                        237000000.0
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                     150.437577
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# ...

# %%
for idx, row in df.iterrows():
    if row['vote_average'] >= 8.5:
        print(f"idx:{idx}, title:{row['title']}")
# Out:
# idx:1881, title:The Shawshank Redemption
# idx:2970, title:There Goes My Baby

# %%
a, b = next(df.iterrows())
b
# Out:
# budget                                                        237000000.0
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                     150.437577
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                      2787965087.0
# ...

# %%
b['vote_average']
# Out:
# 7.2
