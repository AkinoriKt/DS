# %% [markdown]
# ## Lambda function

# %%
def func(a):
    return a + 1

# %%
x = lambda a: a + 1

# %%
func(2)
# Out:
# 3

# %%
x(2)
# Out:
# 3

# %%
file_path = "/home/user/Desktop/image1.png"

# %%
file_path
# Out:
# '/home/user/Desktop/image1.png'

# %%
def get_filename(path):
    file_name = file_path.split('/')[-1].split('.')[0]
    return file_name

# %%
get_filename(file_path)
# Out:
# 'image1'

# %%
x = lambda file_name: file_path.split('/')[-1].split('.')[0]

# %%
x(file_path)
# Out:
# 'image1'
