# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('../../../data/raw/lecture/tmdb_5000_movies.csv')

# %%
len(df)
# Out:
# 4803

# %%
df.corr(numeric_only=True)
# Out:
#                 budget        id  popularity   revenue   runtime  \
# budget        1.000000 -0.089377    0.505414  0.730823  0.269851
# id           -0.089377  1.000000    0.031202 -0.050425 -0.153536
# popularity    0.505414  0.031202    1.000000  0.644724  0.225502
# revenue       0.730823 -0.050425    0.644724  1.000000  0.251093
# runtime       0.269851 -0.153536    0.225502  0.251093  1.000000
# vote_average  0.093146 -0.270595    0.273952  0.197150  0.375046
# vote_count    0.593180 -0.004128    0.778130  0.781487  0.271944
#
#               vote_average  vote_count
# budget            0.093146    0.593180
# id               -0.270595   -0.004128
# popularity        0.273952    0.778130
# revenue           0.197150    0.781487
# runtime           0.375046    0.271944
# vote_average      1.000000    0.312997
# vote_count        0.312997    1.000000

# %%
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
df = df[(df != 0).all(axis=1)]
len(df)
# Out:
# 3227

# %%
df.corr(numeric_only=True)
# Out:
#                 budget        id  popularity   revenue   runtime  \
# budget        1.000000  0.015819    0.431744  0.705306  0.229712
# id            0.015819  1.000000    0.180645  0.031826 -0.034371
# popularity    0.431744  0.180645    1.000000  0.602122  0.182388
# revenue       0.705306  0.031826    0.602122  1.000000  0.233236
# runtime       0.229712 -0.034371    0.182388  0.233236  1.000000
# vote_average -0.035757 -0.050815    0.288189  0.188014  0.386199
# vote_count    0.539997  0.109066    0.749005  0.756143  0.258101
#
#               vote_average  vote_count
# budget           -0.035757    0.539997
# id               -0.050815    0.109066
# popularity        0.288189    0.749005
# revenue           0.188014    0.756143
# runtime           0.386199    0.258101
# vote_average      1.000000    0.380825
# vote_count        0.380825    1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df['release_date']
# Out:
# 0       2009-12-10
# 1       2007-05-19
# 2       2015-10-26
# 3       2012-07-16
# 4       2012-03-07
#            ...
# 4773    1994-09-13
# 4788    1972-03-12
# 4792    1997-11-06
# 4796    2004-10-08
# 4798    1992-09-04
# Name: release_date, Length: 3227, dtype: str

# %%
df['year'] = df['release_date'].apply(lambda x: x.split('-')[0])
df['month'] = df['release_date'].apply(lambda x: x.split('-')[1])

# %%
df['year']
# Out:
# 0       2009
# 1       2007
# 2       2015
# 3       2012
# 4       2012
#         ...
# 4773    1994
# 4788    1972
# 4792    1997
# 4796    2004
# 4798    1992
# Name: year, Length: 3227, dtype: str

# %%
df['month']
# Out:
# 0       12
# 1       05
# 2       10
# 3       07
# 4       03
#         ..
# 4773    09
# 4788    03
# 4792    11
# 4796    10
# 4798    09
# Name: month, Length: 3227, dtype: str

# %%
revenue_df = pd.pivot_table(data=df, values='revenue', columns='year', index='month')
revenue_df
# Out:
# year        1916        1925      1927       1929       1930  1932       1933  \
# month
# 01           NaN         NaN  650422.0        NaN        NaN   NaN        NaN
# 02           NaN         NaN       NaN  4358000.0        NaN   NaN  2240500.0
# 03           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 04           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 05           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 06           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 07           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 08           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 09     8394751.0         NaN       NaN        NaN        NaN   NaN        NaN
# 10           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 11           NaN  22000000.0       NaN        NaN  8000000.0   NaN        NaN
# ...

# %%
df.groupby(['year', 'month']).mean(numeric_only=True)[['revenue']]
# Out:
#                  revenue
# year month
# 1916 09     8.394751e+06
# 1925 11     2.200000e+07
# 1927 01     6.504220e+05
# 1929 02     4.358000e+06
# 1930 11     8.000000e+06
# ...                  ...
# 2016 05     2.747345e+08
#      06     2.562691e+08
#      07     1.703382e+08
#      08     3.275855e+08
#      09     1.586157e+07
#
# [572 rows x 1 columns]

# %%
df.groupby(['year', 'month']).mean(numeric_only=True)[['revenue']].pivot_table(values='revenue', index='month', columns='year')
# Out:
# year        1916        1925      1927       1929       1930  1932       1933  \
# month
# 01           NaN         NaN  650422.0        NaN        NaN   NaN        NaN
# 02           NaN         NaN       NaN  4358000.0        NaN   NaN  2240500.0
# 03           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 04           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 05           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 06           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 07           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 08           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 09     8394751.0         NaN       NaN        NaN        NaN   NaN        NaN
# 10           NaN         NaN       NaN        NaN        NaN   NaN        NaN
# 11           NaN  22000000.0       NaN        NaN  8000000.0   NaN        NaN
# ...

# %%
sns.heatmap(revenue_df, cmap='coolwarm')
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(df.groupby(['year', 'month']).mean(numeric_only=True)[['revenue']].pivot_table(values='revenue', index='month', columns='year'), cmap='coolwarm')
# Out:
# <Axes: xlabel='year', ylabel='month'>
