# %%
import glob
import os
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
glob.glob('../../../data/raw/lecture/public-covid-data/*/*')
# Out:
# ['../../../data/raw/lecture/public-covid-data/rp_im/5.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_im/9.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_im/7.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_im/3.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_im/1.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_im/4.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_im/8.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_im/6.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_im/2.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_msk/5.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_msk/9.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_msk/7.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_msk/3.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_msk/1.nii.gz',
#  '../../../data/raw/lecture/public-covid-data/rp_msk/4.nii.gz',
# ...

# %%
p = Path('../../../data/raw/lecture/public-covid-data/')
p
# Out:
# PosixPath('../../../data/raw/lecture/public-covid-data')

# %%
p_i = p.iterdir()
p_i
# Out:
# <generator object Path.iterdir at 0xffff2d47d460>

# %%
p_i_ = next(p_i)
p_i_
# Out:
# PosixPath('../../../data/raw/lecture/public-covid-data/rp_im')

# %%
p_i_i = p_i_.iterdir()
p_i_i
# Out:
# <generator object Path.iterdir at 0xffff2d47f5a0>

# %%
next(p_i_i)
# Out:
# PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/5.nii.gz')

# %%
p = Path('../../../data/raw/lecture/public-covid-data/')
p
# Out:
# PosixPath('../../../data/raw/lecture/public-covid-data')

# %%
list(p.iterdir())
# Out:
# [PosixPath('../../../data/raw/lecture/public-covid-data/rp_im'),
#  PosixPath('../../../data/raw/lecture/public-covid-data/rp_msk')]

# %%
im_p = list(p.iterdir())[0]
list(im_p.iterdir())
# Out:
# [PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/5.nii.gz'),
#  PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/9.nii.gz'),
#  PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/7.nii.gz'),
#  PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/3.nii.gz'),
#  PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/1.nii.gz'),
#  PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/4.nii.gz'),
#  PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/8.nii.gz'),
#  PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/6.nii.gz'),
#  PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/2.nii.gz')]

# %%
list(im_p.glob('*[6-9]*'))
# Out:
# [PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/9.nii.gz'),
#  PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/7.nii.gz'),
#  PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/8.nii.gz'),
#  PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/6.nii.gz')]

# %%
target_file = list(im_p.iterdir())[0]
target_file
# Out:
# PosixPath('../../../data/raw/lecture/public-covid-data/rp_im/5.nii.gz')

# %%
folder_p, file_name = os.path.split(target_file)
print(folder_p)
print(file_name)
# Out:
# ../../../data/raw/lecture/public-covid-data/rp_im
# 5.nii.gz

# %%
os.path.join(folder_p, file_name)
# Out:
# '../../../data/raw/lecture/public-covid-data/rp_im/5.nii.gz'

# %%
p = Path('../../../data/raw/lecture/public-covid-data/')
new_folder_name = 'new_folder'
new_folder_path = os.path.join(p, new_folder_name)
new_folder_path
# Out:
# '../../../data/raw/lecture/public-covid-data/new_folder'

# %%
os.path.exists(new_folder_path)
# Out:
# False

# %%
if not os.path.exists(new_folder_path):
    os.makedirs(new_folder_path)
