# %%
import os
import pandas as pd
from pathlib import Path

# %%
p = Path('../../../data/raw/lecture/public-covid-data/')

# %%
target_folder = ['rp_im', 'rp_msk']
df_list = []

for folder in p.iterdir():
    if os.path.split(folder)[-1] in target_folder:
        df_list.append(pd.DataFrame({
            'path': [sub_p.as_posix() for sub_p in folder.iterdir()],
            'filename': [os.path.split(sub_p)[-1] for sub_p in folder.iterdir()],
        }))
df = df_list[0].merge(df_list[1], on='filename', suffixes=('_im', '_msk'))
df
# Out:
#                                              path_im  filename  \
# 0  ../../../data/raw/lecture/public-covid-data/rp...  5.nii.gz
# 1  ../../../data/raw/lecture/public-covid-data/rp...  9.nii.gz
# 2  ../../../data/raw/lecture/public-covid-data/rp...  7.nii.gz
# 3  ../../../data/raw/lecture/public-covid-data/rp...  3.nii.gz
# 4  ../../../data/raw/lecture/public-covid-data/rp...  1.nii.gz
# 5  ../../../data/raw/lecture/public-covid-data/rp...  4.nii.gz
# 6  ../../../data/raw/lecture/public-covid-data/rp...  8.nii.gz
# 7  ../../../data/raw/lecture/public-covid-data/rp...  6.nii.gz
# 8  ../../../data/raw/lecture/public-covid-data/rp...  2.nii.gz
#
#                                             path_msk
# 0  ../../../data/raw/lecture/public-covid-data/rp...
# 1  ../../../data/raw/lecture/public-covid-data/rp...
# 2  ../../../data/raw/lecture/public-covid-data/rp...
# 3  ../../../data/raw/lecture/public-covid-data/rp...
# 4  ../../../data/raw/lecture/public-covid-data/rp...
# 5  ../../../data/raw/lecture/public-covid-data/rp...
# 6  ../../../data/raw/lecture/public-covid-data/rp...
# 7  ../../../data/raw/lecture/public-covid-data/rp...
# 8  ../../../data/raw/lecture/public-covid-data/rp...

# %%
p = Path('../../../data/raw/lecture/public-covid-data/')

# %%
target_folders = {'rp_im', 'rp_msk'}
dfs = {}

for folder in p.iterdir():
    if not folder.name in target_folders:
        continue

    files = list(folder.iterdir())
    dfs[folder.name] = pd.DataFrame({
        'filename': [f.name for f in files],
        'path': [f.as_posix() for f in files],
    })

df = dfs['rp_im'].merge(
    dfs['rp_msk'],
    on='filename',
    suffixes=('_im', '_msk'),
)

df
# Out:
#    filename                                            path_im  \
# 0  5.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 1  9.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 2  7.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 3  3.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 4  1.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 5  4.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 6  8.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 7  6.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 8  2.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
#
#                                             path_msk
# 0  ../../../data/raw/lecture/public-covid-data/rp...
# 1  ../../../data/raw/lecture/public-covid-data/rp...
# 2  ../../../data/raw/lecture/public-covid-data/rp...
# 3  ../../../data/raw/lecture/public-covid-data/rp...
# 4  ../../../data/raw/lecture/public-covid-data/rp...
# 5  ../../../data/raw/lecture/public-covid-data/rp...
# 6  ../../../data/raw/lecture/public-covid-data/rp...
# 7  ../../../data/raw/lecture/public-covid-data/rp...
# 8  ../../../data/raw/lecture/public-covid-data/rp...

# %%
dfs.keys()
# Out:
# dict_keys(['rp_im', 'rp_msk'])

# %%
dfs.items()
# Out:
# dict_items([('rp_im',    filename                                               path
# 0  5.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 1  9.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 2  7.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 3  3.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 4  1.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 5  4.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 6  8.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 7  6.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 8  2.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...), ('rp_msk',    filename                                               path
# 0  5.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 1  9.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 2  7.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 3  3.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 4  1.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 5  4.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 6  8.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 7  6.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 8  2.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...)])

# %%
p = Path('../../../data/raw/lecture/public-covid-data/')

target_folders = {'rp_im', 'rp_msk'}
df_dict = {}

for folder in p.iterdir():
    if not folder.name in target_folders:
        continue

    df_dict[folder.name] = pd.DataFrame(
        [
            {
                'path': f.as_posix(),
                'filename': f.name,
            }
            for f in folder.iterdir()
        ] 
    )

df = df_dict['rp_im'].merge(df_dict['rp_msk'], on='filename', suffixes=('_im', '_msk'))
df
# Out:
#                                              path_im  filename  \
# 0  ../../../data/raw/lecture/public-covid-data/rp...  5.nii.gz
# 1  ../../../data/raw/lecture/public-covid-data/rp...  9.nii.gz
# 2  ../../../data/raw/lecture/public-covid-data/rp...  7.nii.gz
# 3  ../../../data/raw/lecture/public-covid-data/rp...  3.nii.gz
# 4  ../../../data/raw/lecture/public-covid-data/rp...  1.nii.gz
# 5  ../../../data/raw/lecture/public-covid-data/rp...  4.nii.gz
# 6  ../../../data/raw/lecture/public-covid-data/rp...  8.nii.gz
# 7  ../../../data/raw/lecture/public-covid-data/rp...  6.nii.gz
# 8  ../../../data/raw/lecture/public-covid-data/rp...  2.nii.gz
#
#                                             path_msk
# 0  ../../../data/raw/lecture/public-covid-data/rp...
# 1  ../../../data/raw/lecture/public-covid-data/rp...
# 2  ../../../data/raw/lecture/public-covid-data/rp...
# 3  ../../../data/raw/lecture/public-covid-data/rp...
# 4  ../../../data/raw/lecture/public-covid-data/rp...
# 5  ../../../data/raw/lecture/public-covid-data/rp...
# 6  ../../../data/raw/lecture/public-covid-data/rp...
# 7  ../../../data/raw/lecture/public-covid-data/rp...
# 8  ../../../data/raw/lecture/public-covid-data/rp...

# %%
for f in folder.iterdir():
    print(f)
# Out:
# ../../../data/raw/lecture/public-covid-data/rp_im/5.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/9.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/7.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/3.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/1.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/4.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/8.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/6.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/2.nii.gz

# %%
files = list(folder.iterdir())
for f in files:
    print(f)
# Out:
# ../../../data/raw/lecture/public-covid-data/rp_im/5.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/9.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/7.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/3.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/1.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/4.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/8.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/6.nii.gz
# ../../../data/raw/lecture/public-covid-data/rp_im/2.nii.gz

# %%
for folder in p.iterdir():
    print(f'foldername: {folder.name}')
    print([f.name for f in folder.iterdir()])
    print([f.as_posix() for f in folder.iterdir()])
    print('*'*30)
# Out:
# foldername: new_folder
# []
# []
# ******************************
# foldername: rp_im
# ['5.nii.gz', '9.nii.gz', '7.nii.gz', '3.nii.gz', '1.nii.gz', '4.nii.gz', '8.nii.gz', '6.nii.gz', '2.nii.gz']
# ['../../../data/raw/lecture/public-covid-data/rp_im/5.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_im/9.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_im/7.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_im/3.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_im/1.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_im/4.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_im/8.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_im/6.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_im/2.nii.gz']
# ******************************
# foldername: rp_msk
# ['5.nii.gz', '9.nii.gz', '7.nii.gz', '3.nii.gz', '1.nii.gz', '4.nii.gz', '8.nii.gz', '6.nii.gz', '2.nii.gz']
# ['../../../data/raw/lecture/public-covid-data/rp_msk/5.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_msk/9.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_msk/7.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_msk/3.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_msk/1.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_msk/4.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_msk/8.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_msk/6.nii.gz', '../../../data/raw/lecture/public-covid-data/rp_msk/2.nii.gz']
# ******************************

# %%
pd.DataFrame([{'filename': f.name, 'path': f.as_posix()} for f in folder.iterdir()])
# Out:
#    filename                                               path
# 0  5.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 1  9.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 2  7.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 3  3.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 4  1.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 5  4.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 6  8.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 7  6.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...
# 8  2.nii.gz  ../../../data/raw/lecture/public-covid-data/rp...

# %% [markdown]
# [()]
