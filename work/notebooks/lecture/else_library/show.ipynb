# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
im = cv2.imread('../../../data/raw/lecture/pic_resources/lenna.png')
im.shape
# Out:
# (220, 220, 3)

# %%
im
# Out:
# array([[[127, 137, 225],
#         [127, 137, 224],
#         [119, 134, 227],
#         ...,
#         [128, 141, 227],
#         [124, 150, 232],
#         [104, 120, 213]],
#
#        [[127, 137, 225],
#         [127, 136, 224],
#         [119, 134, 227],
#         ...,
#         [130, 144, 230],
#         [126, 155, 238],
#         [105, 124, 219]],
#
#        [[122, 137, 227],
#         [118, 134, 224],
#         [117, 133, 228],
#         ...,
#         [106, 113, 209],
#         [ 96,  97, 189],
#         [ 80,  61, 149]],
#
#        ...,
#
#        [[ 60,  28,  90],
#         [ 61,  29,  95],
#         [ 63,  28,  97],
#         ...,
#         [ 68,  42, 126],
#         [ 73,  58, 148],
#         [ 73,  59, 158]],
#
#        [[ 61,  24,  87],
#         [ 62,  27,  92],
#         [ 61,  25,  95],
#         ...,
#         [ 78,  58, 143],
#         [ 80,  67, 167],
#         [ 78,  65, 169]],
#
#        [[ 58,  22,  84],
#         [ 62,  29,  95],
#         [ 59,  24,  93],
#         ...,
#         [ 84,  67, 159],
#         [ 81,  70, 176],
#         [ 80,  71, 182]]], shape=(220, 220, 3), dtype=uint8)

# %%
plt.imshow(im)

# %%
cv2.COLOR_BGR2RGB
# Out:
# 4

# %%
# BGR -> RGB
rgb_im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
rgb_im
# Out:
# array([[[225, 137, 127],
#         [224, 137, 127],
#         [227, 134, 119],
#         ...,
#         [227, 141, 128],
#         [232, 150, 124],
#         [213, 120, 104]],
#
#        [[225, 137, 127],
#         [224, 136, 127],
#         [227, 134, 119],
#         ...,
#         [230, 144, 130],
#         [238, 155, 126],
#         [219, 124, 105]],
#
#        [[227, 137, 122],
#         [224, 134, 118],
#         [228, 133, 117],
#         ...,
#         [209, 113, 106],
#         [189,  97,  96],
#         [149,  61,  80]],
#
#        ...,
#
#        [[ 90,  28,  60],
#         [ 95,  29,  61],
#         [ 97,  28,  63],
#         ...,
#         [126,  42,  68],
#         [148,  58,  73],
#         [158,  59,  73]],
#
#        [[ 87,  24,  61],
#         [ 92,  27,  62],
#         [ 95,  25,  61],
#         ...,
#         [143,  58,  78],
#         [167,  67,  80],
#         [169,  65,  78]],
#
#        [[ 84,  22,  58],
#         [ 95,  29,  62],
#         [ 93,  24,  59],
#         ...,
#         [159,  67,  84],
#         [176,  70,  81],
#         [182,  71,  80]]], shape=(220, 220, 3), dtype=uint8)

# %%
plt.imshow(rgb_im)

# %%
gray_im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_im, cmap='gray')

# %%
crop = im[50:-50, 50:-50, :]
plt.imshow(crop)

# %%
cv2.imwrite('cropped_lenna.png', crop)
# Out:
# True

# %%
crop_load = cv2.imread('cropped_lenna.png')
plt.imshow(crop_load)

# %%
crop_load_rgb = cv2.cvtColor(crop_load, cv2.COLOR_BGR2RGB)
plt.imshow(crop_load_rgb)
